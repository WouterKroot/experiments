# %%
import numpy as np

stepsizes = np.logspace(-0.15, -0.2, 20)
stepsizes = stepsizes.tolist()
stepsizes = stepsizes.sort(reverse=True)

print(stepsizes)
# Out:
# None

# %%
import numpy as np

stepsizes = np.logspace(-0.15, -2, 20)
stepsizes = stepsizes.tolist()  # now it's a Python list
stepsizes.sort(reverse=True)
print(stepsizes)
# Out:
# [0.7079457843841379, 0.5657591401470917, 0.4521298264928948, 0.3613222756796251, 0.2887528741799446, 0.23075859961954892, 0.1844121255921814, 0.1473740615582479, 0.11777486946929414, 0.09412049672680665, 0.07521696219251955, 0.06011008864405584, 0.04803733960364052, 0.03838932944950302, 0.030679063989438565, 0.024517358879792867, 0.019593195106848448, 0.015658019951383658, 0.012513201009886982, 0.01]
